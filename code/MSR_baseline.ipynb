# %% [markdown]
# # A Baseline for the MSR dataset using gigaword and PPMI

# %%
from nltk.corpus import wordnet
import numpy as np
import os
import pandas as pd
from sklearn.metrics import accuracy_score
import vsm
import data_loading


# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load the data

# %%
msr = data_loading.MSR()
dev = msr.dev()
dev.head()
# Out:
#                                               question          a)  \
# id
# 97   His hair and whiskers were shot with gray , an...  chattering
# 727  It was only after a painful and prolonged scen...     ejected
# 19   I went up to the house with the _____ , and sa...   Moonstone
# 846            Would she not have made an _____ queen.        oval
# 903  My clothes were all _____ with dew , and my co...      packed
#
#               b)        c)         d)          e) answer
# id
# 97   picturesque   hopeful   puckered  glistening      d
# 727     consumed  awakened   startled    softened      a
# 19     moonlight    empire     asylum   Inspector      e
# 846    imaginary  enormous  admirable     amateur      d
# 903      charged  supplied   tattered      sodden      e

# %%
vsmdata = '../data/vsmdata'

# %%
giga5 = pd.read_csv(
    os.path.join(vsmdata, 'gigaword_window5-scaled.csv.gz'), index_col=0)

# %%
giga20 = pd.read_csv(
    os.path.join(vsmdata, 'gigaword_window20-flat.csv.gz'), index_col=0)

# %% [markdown]
# ## Calculate PPMI matrix

# %%
giga5_pmi = vsm.pmi(giga5)

# %%
giga20_pmi = vsm.pmi(giga20)

# %%
giga20_pmi.head()
# Out:
#              !         "         $         %      &AMP      &amp         '  \
# !     5.841817  0.643911  0.000000  3.185382  0.000000  0.121197  0.880838
# "     0.643911  2.866995  0.000000  0.000000  0.000000  1.181611  0.000000
# $     0.000000  0.000000  4.212617  0.784733  1.247550  0.808534  0.000000
# %     3.185382  0.000000  0.784733  8.278628  1.848348  1.247424  0.000000
# &AMP  0.000000  0.000000  1.247550  1.848348  5.332599  0.000000  0.431175
#
#              (        (8         )    ...     zagreb  zambia  zealand  \
# !     0.472697  0.364272  0.535979    ...        0.0     0.0  0.00000
# "     0.000000  0.000000  0.000000    ...        0.0     0.0  0.00000
# $     0.525137  0.666451  0.530020    ...        0.0     0.0  0.00000
# %     0.921025  0.806773  0.922745    ...        0.0     0.0  0.26203
# &AMP  0.889812  0.933909  0.939811    ...        0.0     0.0  0.00000
#
#          zebra  zimbabwe      zinc     zloty    zombie  zone       zoo
# !     0.000000       0.0  0.000000  0.000000  1.449382   0.0  0.045402
# "     0.400573       0.0  0.000000  0.000000  1.642623   0.0  0.000000
# $     0.401652       0.0  1.227381  0.509906  0.000000   0.0  0.273820
# %     0.000000       0.0  0.314046  0.000000  0.000000   0.0  0.000000
# &AMP  0.013311       0.0  0.091865  0.000000  0.000000   0.0  0.000000
#
# [5 rows x 5000 columns]

# %%
giga20_pmi.loc["!", "oval"]
# Out:
# 0.0

# %% [markdown]
# ## PPMI Model
# From Inkpen 2007

# %%
def get_synonyms(word):
    synonyms = []
    for syn in wordnet.synsets("good"):
        for l in syn.lemmas():
            synonyms.append(l.name())
    return synonyms

# %%
class PPMIBaseline:
    def __init__(self, corpus_pmi):
        self.corpus_pmi = corpus_pmi
        self.index_to_label = ['a', 'b', 'c', 'd', 'e']
    
    def answer(self, problem):
        scores = []
        question = problem['question']
        scores.append(self.score(question, problem['a)'])) 
        scores.append(self.score(question, problem['b)'])) 
        scores.append(self.score(question, problem['c)'])) 
        scores.append(self.score(question, problem['d)'])) 
        scores.append(self.score(question, problem['e)']))
        return self.index_to_label[np.argmax(scores)]
    
    def ppmi(self, proposal, word):
        try:
            return self.corpus_pmi.loc[proposal, word]
        except KeyError:
            return None
    
    def score(self, sentence, proposal, try_synonyms=True):
        sentence = sentence.lower()
        score = 0
        synonyms = get_synonyms(proposal)
        for word in sentence.split():
            if word == '_____':
                continue
            s = self.ppmi(proposal, word)
            if s is None and try_synonyms:
                for syn in synonyms:
                    s = self.ppmi(syn, word)
                    if s is not None:
                        break 
            score += s if s is not None else 0
        return score

# %% [markdown]
# ## Evaluation

# %%
model = PPMIBaseline(giga20_pmi)

predictions = []
for _, problem in dev.iterrows():
    ans = model.answer(problem)
    predictions.append(ans)

# %%
accuracy_score(dev.loc[:, 'answer'], predictions)
# Out:
# 0.27403846153846156

# %% [markdown]
# Note: part of the reason this does so poorly is that the majority of the answers are not even in the gigaword vocabulary.
# * Before adding synonym matching (giga20): 0.27884615384615385
# * After adding synonym matching (giga20): 0.26442307692307693    :(
#
# Thoughts on why:
# Using synonyms gives more non-zero scores, but doesn't necessarily give more nonzero scores to the correct answer categories. Just the words that have common synonyms.
